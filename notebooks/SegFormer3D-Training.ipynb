# %% [markdown]
# # SegFormer 3D Training
#
# ---
#
# ## 1) Data Pre-Processing
#
# ---

# %% [markdown]
# In ***medical imaging***, particularly when working with ***brain MRI*** scans, it is essential to perform various pre-processing steps to enhance the quality of the images and ensure the ***robustness*** and ***accuracy*** of machine learning models. These pre-processing techniques help ***standardize*** the input data, reduce noise, and highlight relevant features, ultimately ***lightening*** the ***computational load*** on the model and improving its convergence. Common pre-processing steps include:
#
# 1) ***Resampling and Resizing***:
# MRI scans are often acquired with different resolutions and voxel sizes depending on the scanner settings. Resampling the images to a consistent resolution ensures uniformity across the dataset, which is crucial for machine learning models to learn effectively without being biased by variations in image dimensions.
#
# 2) ***Skull Stripping***:
# This process involves removing non-brain tissue, such as the skull and scalp, from MRI images. Skull stripping focuses the analysis on brain tissue, thereby reducing noise and irrelevant features, which can improve the model's ability to extract meaningful patterns from the data.
#
# 3) ***Intensity Normalization***:
# MRI images often have varying intensity ranges due to differences in scanner parameters and acquisition protocols. Normalizing the intensity values to a standard range helps models learn from more consistent input data and reduces variability, leading to more stable and generalizable performance.
#
# 4) ***Noise Reduction (Denoising)***:
# MRI scans can contain random noise, which may obscure critical features. Applying denoising filters such as Gaussian or non-local means can help preserve the relevant anatomical structures while eliminating noise that could negatively impact the model's learning process.
#
# 5) ***Bias Field Correction***:
# MR images sometimes suffer from low-frequency intensity variations, known as bias fields, caused by inhomogeneities in the magnetic field. Correcting these variations ensures more uniform intensity across the brain tissue, improving segmentation and feature extraction.
#
# 6) ***Spatial Alignment (Registration)***:
# Aligning images to a common coordinate space, such as the MNI152 template, ensures that corresponding anatomical regions are in the same location across different subjects. This spatial consistency helps models generalize better and facilitates group analysis.
#
# 7) ***Data Augmentation***:
# Pre-processing can also involve data augmentation techniques, such as random rotations, flips, and elastic deformations. Augmentation increases the diversity of the training dataset, helping models become more robust to variations in real-world MRI scans.
#
# By implementing these pre-processing steps, the computational burden on machine learning models is significantly ***reduced***, as the models can focus on learning meaningful patterns rather than compensating for inconsistencies and noise in the data. Consequently, this leads to faster training times, improved model accuracy, and ***better clinical insights***.
#
# ---

# %%
# The following code relies on the usage of the BraTs 2021 dataset --> https://www.kaggle.com/datasets/dschettler8845/brats-2021-task1

# 1) Build the SegFormer Utils module

# %%
# %%bash
# cd ../segformer-utils/
# python -m build
# cd ../notebooks
# cp ../segformer-utils/dist/*.whl .
# python -m pip install *.whl
# Out:
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for sdist...
# running egg_info
# writing segformer3dutils.egg-info/PKG-INFO
# writing dependency_links to segformer3dutils.egg-info/dependency_links.txt
# writing requirements to segformer3dutils.egg-info/requires.txt
# writing top-level names to segformer3dutils.egg-info/top_level.txt
# reading manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# writing manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# * Building sdist...
# running sdist
# running egg_info
# writing segformer3dutils.egg-info/PKG-INFO
# writing dependency_links to segformer3dutils.egg-info/dependency_links.txt
# writing requirements to segformer3dutils.egg-info/requires.txt
# writing top-level names to segformer3dutils.egg-info/top_level.txt
# reading manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# writing manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# running check
# creating segformer3dutils-0.1.0
# creating segformer3dutils-0.1.0/segformer3dutils
# creating segformer3dutils-0.1.0/segformer3dutils.egg-info
# creating segformer3dutils-0.1.0/segformer3dutils/data_preprocessor
# creating segformer3dutils-0.1.0/segformer3dutils/data_splitter
# creating segformer3dutils-0.1.0/segformer3dutils/model_trainer
# copying files to segformer3dutils-0.1.0...
# copying README.md -> segformer3dutils-0.1.0
# copying setup.py -> segformer3dutils-0.1.0
# copying segformer3dutils/__init__.py -> segformer3dutils-0.1.0/segformer3dutils
# copying segformer3dutils.egg-info/PKG-INFO -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# copying segformer3dutils.egg-info/SOURCES.txt -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# copying segformer3dutils.egg-info/dependency_links.txt -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# copying segformer3dutils.egg-info/requires.txt -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# copying segformer3dutils.egg-info/top_level.txt -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# copying segformer3dutils/data_preprocessor/__init__.py -> segformer3dutils-0.1.0/segformer3dutils/data_preprocessor
# copying segformer3dutils/data_splitter/__init__.py -> segformer3dutils-0.1.0/segformer3dutils/data_splitter
# copying segformer3dutils/data_splitter/create_train_val_test_csv.py -> segformer3dutils-0.1.0/segformer3dutils/data_splitter
# copying segformer3dutils/model_trainer/__init__.py -> segformer3dutils-0.1.0/segformer3dutils/model_trainer
# copying segformer3dutils.egg-info/SOURCES.txt -> segformer3dutils-0.1.0/segformer3dutils.egg-info
# Writing segformer3dutils-0.1.0/setup.cfg
# Creating tar archive
# removing 'segformer3dutils-0.1.0' (and everything under it)
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - setuptools >= 40.8.0
# * Getting build dependencies for wheel...
# running egg_info
# writing segformer3dutils.egg-info/PKG-INFO
# writing dependency_links to segformer3dutils.egg-info/dependency_links.txt
# writing requirements to segformer3dutils.egg-info/requires.txt
# writing top-level names to segformer3dutils.egg-info/top_level.txt
# reading manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# writing manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# * Building wheel...
# running bdist_wheel
# running build
# running build_py
# creating build/lib/segformer3dutils
# copying segformer3dutils/__init__.py -> build/lib/segformer3dutils
# creating build/lib/segformer3dutils/model_trainer
# copying segformer3dutils/model_trainer/__init__.py -> build/lib/segformer3dutils/model_trainer
# creating build/lib/segformer3dutils/data_splitter
# copying segformer3dutils/data_splitter/__init__.py -> build/lib/segformer3dutils/data_splitter
# copying segformer3dutils/data_splitter/create_train_val_test_csv.py -> build/lib/segformer3dutils/data_splitter
# creating build/lib/segformer3dutils/data_preprocessor
# copying segformer3dutils/data_preprocessor/__init__.py -> build/lib/segformer3dutils/data_preprocessor
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/segformer3dutils
# creating build/bdist.linux-x86_64/wheel/segformer3dutils/model_trainer
# copying build/lib/segformer3dutils/model_trainer/__init__.py -> build/bdist.linux-x86_64/wheel/./segformer3dutils/model_trainer
# creating build/bdist.linux-x86_64/wheel/segformer3dutils/data_splitter
# copying build/lib/segformer3dutils/data_splitter/__init__.py -> build/bdist.linux-x86_64/wheel/./segformer3dutils/data_splitter
# copying build/lib/segformer3dutils/data_splitter/create_train_val_test_csv.py -> build/bdist.linux-x86_64/wheel/./segformer3dutils/data_splitter
# creating build/bdist.linux-x86_64/wheel/segformer3dutils/data_preprocessor
# copying build/lib/segformer3dutils/data_preprocessor/__init__.py -> build/bdist.linux-x86_64/wheel/./segformer3dutils/data_preprocessor
# copying build/lib/segformer3dutils/__init__.py -> build/bdist.linux-x86_64/wheel/./segformer3dutils
# running install_egg_info
# running egg_info
# writing segformer3dutils.egg-info/PKG-INFO
# writing dependency_links to segformer3dutils.egg-info/dependency_links.txt
# writing requirements to segformer3dutils.egg-info/requires.txt
# writing top-level names to segformer3dutils.egg-info/top_level.txt
# reading manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# writing manifest file 'segformer3dutils.egg-info/SOURCES.txt'
# Copying segformer3dutils.egg-info to build/bdist.linux-x86_64/wheel/./segformer3dutils-0.1.0-py3.11.egg-info
# running install_scripts
# creating build/bdist.linux-x86_64/wheel/segformer3dutils-0.1.0.dist-info/WHEEL
# creating '/mnt/c/Users/adarnall/01-Personal-Work-Projects/SegFormer-4-MSLesSeg/segformer-utils/dist/.tmp-3bs_6qw8/segformer3dutils-0.1.0-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'segformer3dutils/__init__.py'
# adding 'segformer3dutils/data_preprocessor/__init__.py'
# adding 'segformer3dutils/data_splitter/__init__.py'
# adding 'segformer3dutils/data_splitter/create_train_val_test_csv.py'
# adding 'segformer3dutils/model_trainer/__init__.py'
# adding 'segformer3dutils-0.1.0.dist-info/METADATA'
# adding 'segformer3dutils-0.1.0.dist-info/WHEEL'
# adding 'segformer3dutils-0.1.0.dist-info/top_level.txt'
# adding 'segformer3dutils-0.1.0.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# Successfully built segformer3dutils-0.1.0.tar.gz and segformer3dutils-0.1.0-py3-none-any.whl
# Processing ./segformer3dutils-0.1.0-py3-none-any.whl
# Requirement already satisfied: accelerate==0.23.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.23.0)
# Requirement already satisfied: datasets==2.14.5 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.14.5)
# Requirement already satisfied: evaluate==0.4.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.4.1)
# Requirement already satisfied: einops==0.7.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.7.0)
# Requirement already satisfied: h5py==3.9.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (3.9.0)
# Requirement already satisfied: imageio==2.33.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.33.0)
# Requirement already satisfied: kornia==0.7.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.7.2)
# Requirement already satisfied: kornia-rs==0.1.3 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.1.3)
# Requirement already satisfied: lightning==2.0.9 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.0.9)
# Requirement already satisfied: matplotlib==3.7.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.1.6)
# Requirement already satisfied: monai==1.2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (1.2.0)
# Requirement already satisfied: nibabel==5.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (5.1.0)
# Requirement already satisfied: opencv-contrib-python==4.7.0.72 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.7.0.72)
# Requirement already satisfied: opencv-python==4.7.0.72 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.7.0.72)
# Requirement already satisfied: opencv-python-headless==4.7.0.72 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.7.0.72)
# Requirement already satisfied: opt-einsum==3.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (3.3.0)
# Requirement already satisfied: protobuf==4.22.3 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.22.3)
# Requirement already satisfied: requests==2.28.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.28.1)
# Requirement already satisfied: safetensors==0.3.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.3.1)
# Requirement already satisfied: scikit-image==0.23.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.23.1)
# Requirement already satisfied: scikit-learn==1.2.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (1.2.2)
# Requirement already satisfied: scipy==1.13.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (1.13.0)
# Requirement already satisfied: termcolor==2.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.3.0)
# Requirement already satisfied: timm==0.6.13 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.6.13)
# Requirement already satisfied: torch-geometric==2.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.3.0)
# Requirement already satisfied: torch-summary==1.4.5 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (1.4.5)
# Requirement already satisfied: torchmetrics==0.11.4 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.11.4)
# Requirement already satisfied: torchsummary==1.5.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (1.5.1)
# Requirement already satisfied: tqdm==4.65.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.65.0)
# Requirement already satisfied: typing_extensions==4.8.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (4.8.0)
# Requirement already satisfied: wandb==0.15.12 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.15.12)
# Requirement already satisfied: torch==2.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.1.0)
# Requirement already satisfied: torchaudio==2.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (2.1.0)
# Requirement already satisfied: torchvision==0.16.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from segformer3dutils==0.1.0) (0.16.0)
# Requirement already satisfied: numpy>=1.17 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from accelerate==0.23.0->segformer3dutils==0.1.0) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from accelerate==0.23.0->segformer3dutils==0.1.0) (24.2)
# Requirement already satisfied: psutil in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from accelerate==0.23.0->segformer3dutils==0.1.0) (6.1.1)
# Requirement already satisfied: pyyaml in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from accelerate==0.23.0->segformer3dutils==0.1.0) (6.0.2)
# Requirement already satisfied: huggingface-hub in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from accelerate==0.23.0->segformer3dutils==0.1.0) (0.28.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (19.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (0.3.7)
# Requirement already satisfied: pandas in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (2.2.3)
# Requirement already satisfied: xxhash in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (0.70.15)
# Requirement already satisfied: fsspec<2023.9.0,>=2023.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from fsspec[http]<2023.9.0,>=2023.1.0->datasets==2.14.5->segformer3dutils==0.1.0) (2023.6.0)
# Requirement already satisfied: aiohttp in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from datasets==2.14.5->segformer3dutils==0.1.0) (3.11.12)
# Requirement already satisfied: responses<0.19 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from evaluate==0.4.1->segformer3dutils==0.1.0) (0.18.0)
# Requirement already satisfied: pillow>=8.3.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from imageio==2.33.0->segformer3dutils==0.1.0) (11.1.0)
# Requirement already satisfied: Jinja2<5.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (3.1.5)
# Requirement already satisfied: arrow<3.0,>=1.2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (1.3.0)
# Requirement already satisfied: backoff<4.0,>=2.2.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (2.2.1)
# Requirement already satisfied: beautifulsoup4<6.0,>=4.8.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (4.13.3)
# Requirement already satisfied: click<10.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (8.1.8)
# Requirement already satisfied: croniter<1.5.0,>=1.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (1.4.1)
# Requirement already satisfied: dateutils<2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.6.12)
# Requirement already satisfied: deepdiff<8.0,>=5.7.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (7.0.1)
# Requirement already satisfied: fastapi<2.0,>=0.92.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.115.8)
# Requirement already satisfied: inquirer<5.0,>=2.10.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (3.4.0)
# Requirement already satisfied: lightning-cloud>=0.5.38 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.5.70)
# Requirement already satisfied: lightning-utilities<2.0,>=0.7.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.12.0)
# Requirement already satisfied: pydantic<2.2.0,>=1.7.4 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (2.1.1)
# Requirement already satisfied: python-multipart<2.0,>=0.0.5 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.0.20)
# Requirement already satisfied: rich<15.0,>=12.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (13.9.4)
# Requirement already satisfied: starlette in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.45.3)
# Requirement already satisfied: starsessions<2.0,>=1.2.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (1.3.0)
# Requirement already satisfied: traitlets<7.0,>=5.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (5.14.3)
# Requirement already satisfied: urllib3<4.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (1.26.20)
# Requirement already satisfied: uvicorn<2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (0.34.0)
# Requirement already satisfied: websocket-client<3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (1.8.0)
# Requirement already satisfied: websockets<13.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (12.0)
# Requirement already satisfied: pytorch-lightning in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning==2.0.9->segformer3dutils==0.1.0) (2.5.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from matplotlib==3.7.1->segformer3dutils==0.1.0) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from requests==2.28.1->segformer3dutils==0.1.0) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from requests==2.28.1->segformer3dutils==0.1.0) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from requests==2.28.1->segformer3dutils==0.1.0) (2025.1.31)
# Requirement already satisfied: networkx>=2.8 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from scikit-image==0.23.1->segformer3dutils==0.1.0) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from scikit-image==0.23.1->segformer3dutils==0.1.0) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from scikit-image==0.23.1->segformer3dutils==0.1.0) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from scikit-learn==1.2.2->segformer3dutils==0.1.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from scikit-learn==1.2.2->segformer3dutils==0.1.0) (3.5.0)
# Requirement already satisfied: filelock in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (3.17.0)
# Requirement already satisfied: sympy in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (1.13.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from torch==2.1.0->segformer3dutils==0.1.0) (2.1.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (3.1.44)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (2.20.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (0.4.0)
# Requirement already satisfied: pathtools in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (0.1.2)
# Requirement already satisfied: setproctitle in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (1.3.4)
# Requirement already satisfied: setuptools in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (75.8.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from wandb==0.15.12->segformer3dutils==0.1.0) (1.4.4)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1.0->segformer3dutils==0.1.0) (12.8.61)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from arrow<3.0,>=1.2.0->lightning==2.0.9->segformer3dutils==0.1.0) (2.9.0.20241206)
# Requirement already satisfied: soupsieve>1.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from beautifulsoup4<6.0,>=4.8.0->lightning==2.0.9->segformer3dutils==0.1.0) (2.6)
# Requirement already satisfied: pytz in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from dateutils<2.0->lightning==2.0.9->segformer3dutils==0.1.0) (2025.1)
# Requirement already satisfied: ordered-set<4.2.0,>=4.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from deepdiff<8.0,>=5.7.0->lightning==2.0.9->segformer3dutils==0.1.0) (4.1.0)
# Requirement already satisfied: six>=1.4.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from docker-pycreds>=0.4.0->wandb==0.15.12->segformer3dutils==0.1.0) (1.17.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from aiohttp->datasets==2.14.5->segformer3dutils==0.1.0) (1.18.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.15.12->segformer3dutils==0.1.0) (4.0.12)
# Requirement already satisfied: blessed>=1.19.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (1.20.0)
# Requirement already satisfied: editor>=1.6.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (1.6.6)
# Requirement already satisfied: readchar>=4.2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (4.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from Jinja2<5.0->lightning==2.0.9->segformer3dutils==0.1.0) (3.0.2)
# Requirement already satisfied: pyjwt in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning-cloud>=0.5.38->lightning==2.0.9->segformer3dutils==0.1.0) (2.10.1)
# Requirement already satisfied: boto3 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from lightning-cloud>=0.5.38->lightning==2.0.9->segformer3dutils==0.1.0) (1.36.18)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from pydantic<2.2.0,>=1.7.4->lightning==2.0.9->segformer3dutils==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.4.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from pydantic<2.2.0,>=1.7.4->lightning==2.0.9->segformer3dutils==0.1.0) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from rich<15.0,>=12.3.0->lightning==2.0.9->segformer3dutils==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from rich<15.0,>=12.3.0->lightning==2.0.9->segformer3dutils==0.1.0) (2.19.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from starlette->lightning==2.0.9->segformer3dutils==0.1.0) (4.8.0)
# Requirement already satisfied: itsdangerous<3.0.0,>=2.0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from starsessions<2.0,>=1.2.1->lightning==2.0.9->segformer3dutils==0.1.0) (2.2.0)
# Requirement already satisfied: h11>=0.8 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from uvicorn<2.0->lightning==2.0.9->segformer3dutils==0.1.0) (0.14.0)
# Requirement already satisfied: tzdata>=2022.7 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from pandas->datasets==2.14.5->segformer3dutils==0.1.0) (2025.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from sympy->torch==2.1.0->segformer3dutils==0.1.0) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from anyio<5,>=3.6.2->starlette->lightning==2.0.9->segformer3dutils==0.1.0) (1.3.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from blessed>=1.19.0->inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (0.2.13)
# Requirement already satisfied: runs in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from editor>=1.6.0->inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (1.2.2)
# Requirement already satisfied: xmod in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from editor>=1.6.0->inquirer<5.0,>=2.10.0->lightning==2.0.9->segformer3dutils==0.1.0) (1.8.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.15.12->segformer3dutils==0.1.0) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0,>=12.3.0->lightning==2.0.9->segformer3dutils==0.1.0) (0.1.2)
# Requirement already satisfied: botocore<1.37.0,>=1.36.18 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from boto3->lightning-cloud>=0.5.38->lightning==2.0.9->segformer3dutils==0.1.0) (1.36.18)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from boto3->lightning-cloud>=0.5.38->lightning==2.0.9->segformer3dutils==0.1.0) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/drew/miniconda3/envs/segformer/lib/python3.11/site-packages (from boto3->lightning-cloud>=0.5.38->lightning==2.0.9->segformer3dutils==0.1.0) (0.11.2)
# Installing collected packages: segformer3dutils
# Successfully installed segformer3dutils-0.1.0

# %%
from segformer3dutils.data_splitter.create_train_val_test_csv import create_train_val_test_csv_from_data_folder

# %%
# Create the appropriate metadata for the BraTs 2021 dataset
create_train_val_test_csv_from_data_folder(folder_dir="../data/brats2021_seg/Brats2021/BraTS2021_Training_Data", 
                          append_dir="../data/brats2021_seg", save_dir="../data/brats2021_seg", 
                          train_split_perc=0.85, val_split_perc=0.10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Create the appropriate metadata for the BraTs 2021 dataset
# ----> 2 create_train_val_test_csv_from_data_folder(folder_dir="../data/brats2021_seg/Brats2021/BraTS2021_Training_Data",
#       3                           append_dir="../data/brats2021_seg", save_dir="../data/brats2021_seg",
#       4                           train_split_perc=0.85, val_split_perc=0.10)
#
# File ~/miniconda3/envs/segformer/lib/python3.11/site-packages/segformer3dutils/data_splitter/create_train_val_test_csv.py:94, in create_train_val_test_csv_from_data_folder(folder_dir, append_dir, save_dir, train_split_perc, val_split_perc)
#      91 validation_sample_case_name = np.array(case_name)[val_idx]
#      93 # dictionary object to get converte to dataframe
# ---> 94 train_data = {"data_path": train_dp, "label_path": train_fold_cn}
#      95 valid_data = {"data_path": valid_dp, "label_path": valid_fold_cn}
#      97 train_df = create_pandas_df(train_data)
#
# NameError: name 'train_dp' is not defined
